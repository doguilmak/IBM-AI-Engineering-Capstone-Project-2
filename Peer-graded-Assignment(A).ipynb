# %% [markdown]
# ### 1. Assignment Topic:
#
# In this project, you will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in labs 3.p In this course project, you will build a regression model using the deep learning Keras library, and then you will experiment with increasing the number of training epochs and changing number of hidden layers and you will see how changing these parameters impacts the performance of the model.
#
# ## Increasing the Number of Training Epochs - 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Concrete Data:
#
# For your convenience, the data can be found here again: https://cocl.us/concrete_data. To recap, the predictors in the data of concrete strength include:
#
# 1-Cement
#
# 2-Blast Furnace Slag
#
# 3-Fly Ash
#
# 4-Water
#
# 5-Superplasticizer
#
# 6-Coarse Aggregate
#
# 7-Fine Aggregate

# %%
concrete_data = pd.read_csv('concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# #### Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# ### Split data into predictors and target
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

target = concrete_data["Strength"]
predictors = concrete_data.drop(["Strength", "Age"], axis=1)

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate
# 0            1040.0           676.0
# 1            1055.0           676.0
# 2             932.0           594.0
# 3             932.0           594.0
# 4             978.4           825.5

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# ### Normalize predictors and target
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate
# 0          0.862735       -1.217079
# 1          1.055651       -1.217079
# 2         -0.526262       -2.239829
# 3         -0.526262       -2.239829
# 4          0.070492        0.647569

# %%
n_cols = predictors_norm.shape[1]  # number of predictors
n_cols
# Out:
# 7

# %% [markdown]
# ### Importing Keras Libraries

# %%
import warnings
warnings.filterwarnings("ignore")
import keras

# %% [markdown]
# #### Importing the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ### Building Regression Model

# %%
# define regression model
def regression_model():
    # 1-Create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # 2-Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# #### The above function creates a model that has one hidden layer with 10 neurons and a ReLU activation function. It uses the adam optimizer and the mean squared error as the loss function.
#
# Importing scikit-learn in order to randomly split the data into a training and test sets.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### We will train and test the model at the same time using the fit method. We will leave out 30% of the data for validation.

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

# %% [markdown]
# #### Train and Test the Network

# %%
model = regression_model()
# Out:
# WARNING:tensorflow:From /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# #### We will train the model for 60 epochs.

# %%
epochs = 60
model.fit(X_train, y_train, epochs=epochs, verbose=1)
# Out:
# Epoch 1/60
# 721/721 [==============================] - 0s 82us/step - loss: 150.0611
# Epoch 2/60
# 721/721 [==============================] - 0s 83us/step - loss: 146.7458
# Epoch 3/60
# 721/721 [==============================] - 0s 79us/step - loss: 146.7263
# Epoch 4/60
# 721/721 [==============================] - 0s 78us/step - loss: 193.8598
# Epoch 5/60
# 721/721 [==============================] - 0s 65us/step - loss: 146.6776
# Epoch 6/60
# 721/721 [==============================] - 0s 79us/step - loss: 146.7609
# Epoch 7/60
# 721/721 [==============================] - 0s 84us/step - loss: 157.8986
# Epoch 8/60
# 721/721 [==============================] - 0s 83us/step - loss: 174.1539
# Epoch 9/60
# 721/721 [==============================] - 0s 77us/step - loss: 155.7956
# Epoch 10/60
# 721/721 [==============================] - 0s 85us/step - loss: 144.3979
# Epoch 11/60
# 721/721 [==============================] - 0s 64us/step - loss: 144.1995
# Epoch 12/60
# 721/721 [==============================] - 0s 79us/step - loss: 142.2008
# Epoch 13/60
# 721/721 [==============================] - 0s 83us/step - loss: 148.7331
# Epoch 14/60
# 721/721 [==============================] - 0s 83us/step - loss: 152.8499
# Epoch 15/60
# 721/721 [==============================] - 0s 80us/step - loss: 152.6505
# Epoch 16/60
# 721/721 [==============================] - 0s 82us/step - loss: 147.6510
# Epoch 17/60
# 721/721 [==============================] - 0s 79us/step - loss: 147.6858
# Epoch 18/60
# 721/721 [==============================] - 0s 63us/step - loss: 142.6725
# Epoch 19/60
# 721/721 [==============================] - 0s 65us/step - loss: 141.4945
# Epoch 20/60
# 721/721 [==============================] - 0s 78us/step - loss: 143.9908
# Epoch 21/60
